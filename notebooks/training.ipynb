# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5

# Pindah ke direktori yolov5 (untuk instalasi requirements)
# %cd yolov5

# Install dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17511, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 17511 (delta 5), reused 0 (delta 0), pack-reused 17491 (from 3)
# Receiving objects: 100% (17511/17511), 16.62 MiB | 18.80 MiB/s, done.
# Resolving deltas: 100% (12000/12000), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
# ...

# %%
import zipfile
import os

zip_path = 'dataset.zip'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/yolov5/')

# %%
# !ls
# Out:
#  benchmarks.py	  'Emergency Vehicle.v1i.yolov5pytorch'   README.zh-CN.md
#  CITATION.cff	   export.py				  requirements.txt
#  classify	   hubconf.py				  segment
#  CONTRIBUTING.md   LICENSE				  train.py
#  data		   models				  tutorial.ipynb
#  dataset	   __pycache__				  utils
#  dataset.zip	   pyproject.toml			  val.py
#  detect.py	   README.md

# %%
# Jalankan training YOLOv5 di Google Colab
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/yolov5/dataset/data.yaml --weights yolov5n.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-07 11:36:13.311083: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751888173.364749   18132 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751888173.381701   18132 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !zip -r exp2_results.zip runs/train/exp2
# Out:
#   adding: runs/train/exp2/ (stored 0%)
#   adding: runs/train/exp2/events.out.tfevents.1751886720.d7dcc5ba764b.12170.0 (deflated 32%)
#   adding: runs/train/exp2/PR_curve.png (deflated 13%)
#   adding: runs/train/exp2/weights/ (stored 0%)
#   adding: runs/train/exp2/weights/last.pt (deflated 14%)
#   adding: runs/train/exp2/weights/best.pt (deflated 14%)
#   adding: runs/train/exp2/train_batch0.jpg (deflated 2%)
#   adding: runs/train/exp2/labels_correlogram.jpg (deflated 45%)
#   adding: runs/train/exp2/hyp.yaml (deflated 45%)
#   adding: runs/train/exp2/val_batch0_pred.jpg (deflated 9%)
#   adding: runs/train/exp2/val_batch0_labels.jpg (deflated 9%)
#   adding: runs/train/exp2/val_batch1_pred.jpg (deflated 9%)
#   adding: runs/train/exp2/F1_curve.png (deflated 16%)
#   adding: runs/train/exp2/val_batch2_pred.jpg (deflated 9%)
#   adding: runs/train/exp2/results.csv (deflated 75%)
#   adding: runs/train/exp2/labels.jpg (deflated 37%)
# ...

# %%
# !python export.py --weights runs/train/exp17/weights/best.pt --include torchscript
